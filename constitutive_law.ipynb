# %%
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import math
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %%
df_1 = pd.read_csv('5STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] # strain rate 10^-2
df_2 = pd.read_csv('10STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_3 = pd.read_csv('15STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_4 = pd.read_csv('20STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_5 = pd.read_csv('25STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_6= pd.read_csv('30STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_7 = pd.read_csv('35STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_8 = pd.read_csv('40STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_9 = pd.read_csv('45STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_10 = pd.read_csv('50STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_11 = pd.read_csv('55STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_12 = pd.read_csv('60STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_13 = pd.read_csv('65STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_14 = pd.read_csv('70STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_15 = pd.read_csv('75STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_16 = pd.read_csv('80STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_17 = pd.read_csv('85STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_18 = pd.read_csv('90STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_19 = pd.read_csv('95STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']]
# Out:
# /var/folders/y3/y01h3w0s4sldyhwtlxfpx31c0000gn/T/ipykernel_84088/1563757785.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_1 = pd.read_csv('5STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] # strain rate 10^-2
# /var/folders/y3/y01h3w0s4sldyhwtlxfpx31c0000gn/T/ipykernel_84088/1563757785.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_2 = pd.read_csv('10STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']]
# /var/folders/y3/y01h3w0s4sldyhwtlxfpx31c0000gn/T/ipykernel_84088/1563757785.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_3 = pd.read_csv('15STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']]
# ...

# %%
df_20 = pd.read_csv('103-5STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] # strain rate 10^-3
df_21 = pd.read_csv('103-10STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_22 = pd.read_csv('103-15STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_23 = pd.read_csv('103-20STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_24 = pd.read_csv('103-25STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_25 = pd.read_csv('103-30STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_26 = pd.read_csv('103-35STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_27 = pd.read_csv('103-40STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_28 = pd.read_csv('103-45STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_29 = pd.read_csv('103-50STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_30 = pd.read_csv('103-55STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_31 = pd.read_csv('103-60STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_32 = pd.read_csv('103-65STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_33 = pd.read_csv('103-70STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_34 = pd.read_csv('103-75STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_35 = pd.read_csv('103-80STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_36 = pd.read_csv('103-85STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_37 = pd.read_csv('103-90STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_38 = pd.read_csv('103-95STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']]
# Out:
# /var/folders/y3/y01h3w0s4sldyhwtlxfpx31c0000gn/T/ipykernel_84088/2676745754.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_20 = pd.read_csv('103-5STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] # strain rate 10^-3
# /var/folders/y3/y01h3w0s4sldyhwtlxfpx31c0000gn/T/ipykernel_84088/2676745754.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_21 = pd.read_csv('103-10STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']]
# /var/folders/y3/y01h3w0s4sldyhwtlxfpx31c0000gn/T/ipykernel_84088/2676745754.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_22 = pd.read_csv('103-15STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']]
# ...

# %%
df_39 = pd.read_csv('104-5STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] # strain rate 10^-4
df_40 = pd.read_csv('104-10STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_41 = pd.read_csv('104-15STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_42 = pd.read_csv('104-20STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_43 = pd.read_csv('104-25STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_44 = pd.read_csv('104-30STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_45 = pd.read_csv('104-35STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_46 = pd.read_csv('104-40STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_47 = pd.read_csv('104-45STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_48 = pd.read_csv('104-50STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_49 = pd.read_csv('104-55STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_50 = pd.read_csv('104-60STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_51 = pd.read_csv('104-65STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_52 = pd.read_csv('104-70STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_53 = pd.read_csv('104-75STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_54 = pd.read_csv('104-80STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_55 = pd.read_csv('104-85STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_56 = pd.read_csv('104-90STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_57 = pd.read_csv('104-95STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']]
# Out:
# /var/folders/y3/y01h3w0s4sldyhwtlxfpx31c0000gn/T/ipykernel_84088/497223867.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_39 = pd.read_csv('104-5STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] # strain rate 10^-4
# /var/folders/y3/y01h3w0s4sldyhwtlxfpx31c0000gn/T/ipykernel_84088/497223867.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_40 = pd.read_csv('104-10STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']]
# /var/folders/y3/y01h3w0s4sldyhwtlxfpx31c0000gn/T/ipykernel_84088/497223867.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_41 = pd.read_csv('104-15STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']]
# ...

# %%
df_58 = pd.read_csv('105-5STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] # strain rate 10^-5
df_59 = pd.read_csv('105-10STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_60 = pd.read_csv('105-15STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_61 = pd.read_csv('105-20STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_62 = pd.read_csv('105-25STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_63 = pd.read_csv('105-30STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_64 = pd.read_csv('105-35STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_65 = pd.read_csv('105-40STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_66 = pd.read_csv('105-45STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_67 = pd.read_csv('105-50STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_68 = pd.read_csv('105-55STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_69 = pd.read_csv('105-60STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_70 = pd.read_csv('105-65STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_71 = pd.read_csv('105-70STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_72 = pd.read_csv('105-75STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_73 = pd.read_csv('105-80STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_74 = pd.read_csv('105-85STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_75 = pd.read_csv('105-90STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] 
df_76 = pd.read_csv('105-95STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']]
# Out:
# /var/folders/y3/y01h3w0s4sldyhwtlxfpx31c0000gn/T/ipykernel_84088/131091397.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_58 = pd.read_csv('105-5STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']] # strain rate 10^-5
# /var/folders/y3/y01h3w0s4sldyhwtlxfpx31c0000gn/T/ipykernel_84088/131091397.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_59 = pd.read_csv('105-10STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']]
# /var/folders/y3/y01h3w0s4sldyhwtlxfpx31c0000gn/T/ipykernel_84088/131091397.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_60 = pd.read_csv('105-15STR_STR.OUT',delim_whitespace=True)[['E11','SCAU11']]
# ...

# %%
df_1['strain_rate'] = math.pow(10,-2)
df_2['strain_rate'] = math.pow(10,-2)
df_3['strain_rate'] = math.pow(10,-2)
df_4['strain_rate'] = math.pow(10,-2)
df_5['strain_rate'] = math.pow(10,-2)
df_6['strain_rate'] = math.pow(10,-2)
df_7['strain_rate'] = math.pow(10,-2)
df_8['strain_rate'] = math.pow(10,-2)
df_9['strain_rate'] = math.pow(10,-2)
df_10['strain_rate'] = math.pow(10,-2)
df_11['strain_rate'] = math.pow(10,-2)
df_12['strain_rate'] = math.pow(10,-2)
df_13['strain_rate'] = math.pow(10,-2)
df_14['strain_rate'] = math.pow(10,-2)
df_15['strain_rate'] = math.pow(10,-2)
df_16['strain_rate'] = math.pow(10,-2)
df_17['strain_rate'] = math.pow(10,-2)
df_18['strain_rate'] = math.pow(10,-2)
df_19['strain_rate'] = math.pow(10,-2)

df_20['strain_rate'] = math.pow(10,-3)
df_21['strain_rate'] = math.pow(10,-3)
df_22['strain_rate'] = math.pow(10,-3)
df_23['strain_rate'] = math.pow(10,-3)
df_24['strain_rate'] = math.pow(10,-3)
df_25['strain_rate'] = math.pow(10,-3)
df_26['strain_rate'] = math.pow(10,-3)
df_27['strain_rate'] = math.pow(10,-3)
df_28['strain_rate'] = math.pow(10,-3)
df_29['strain_rate'] = math.pow(10,-3)
df_30['strain_rate'] = math.pow(10,-3)
df_31['strain_rate'] = math.pow(10,-3)
df_32['strain_rate'] = math.pow(10,-3)
df_33['strain_rate'] = math.pow(10,-3)
df_34['strain_rate'] = math.pow(10,-3)
df_35['strain_rate'] = math.pow(10,-3)
df_36['strain_rate'] = math.pow(10,-3)
df_37['strain_rate'] = math.pow(10,-3)
df_38['strain_rate'] = math.pow(10,-3)



df_39['strain_rate'] = math.pow(10,-4)
df_40['strain_rate'] = math.pow(10,-4)
df_41['strain_rate'] = math.pow(10,-4)
df_42['strain_rate'] = math.pow(10,-4)
df_43['strain_rate'] = math.pow(10,-4)
df_44['strain_rate'] = math.pow(10,-4)
df_45['strain_rate'] = math.pow(10,-4)
df_46['strain_rate'] = math.pow(10,-4)
df_47['strain_rate'] = math.pow(10,-4)
df_48['strain_rate'] = math.pow(10,-4)
df_49['strain_rate'] = math.pow(10,-4)
df_50['strain_rate'] = math.pow(10,-4)
df_51['strain_rate'] = math.pow(10,-4)
df_52['strain_rate'] = math.pow(10,-4)
df_53['strain_rate'] = math.pow(10,-4)
df_54['strain_rate'] = math.pow(10,-4)
df_55['strain_rate'] = math.pow(10,-4)
df_56['strain_rate'] = math.pow(10,-4)
df_57['strain_rate'] = math.pow(10,-4)



df_58['strain_rate'] = math.pow(10,-5)
df_59['strain_rate'] = math.pow(10,-5)
df_60['strain_rate'] = math.pow(10,-5)
df_61['strain_rate'] = math.pow(10,-5)
df_62['strain_rate'] = math.pow(10,-5)
df_63['strain_rate'] = math.pow(10,-5)
df_64['strain_rate'] = math.pow(10,-5)
df_65['strain_rate'] = math.pow(10,-5)
df_66['strain_rate'] = math.pow(10,-5)
df_67['strain_rate'] = math.pow(10,-5)
df_68['strain_rate'] = math.pow(10,-5)
df_69['strain_rate'] = math.pow(10,-5)
df_70['strain_rate'] = math.pow(10,-5)
df_71['strain_rate'] = math.pow(10,-5)
df_72['strain_rate'] = math.pow(10,-5)
df_73['strain_rate'] = math.pow(10,-5)
df_74['strain_rate'] = math.pow(10,-5)
df_75['strain_rate'] = math.pow(10,-5)
df_76['strain_rate'] = math.pow(10,-5)




df_19
# Out:
#           E11      SCAU11  strain_rate  grain_size
# 0    0.000000  103.590000         0.01    0.000095
# 1    0.000667  104.063333         0.01    0.000095
# 2    0.001429  104.581429         0.01    0.000095
# 3    0.002267  105.183333         0.01    0.000095
# 4    0.003161  105.831935         0.01    0.000095
# ..        ...         ...          ...         ...
# 96   0.095000  158.131954         0.01    0.000095
# 97   0.096000  158.570977         0.01    0.000095
# 98   0.097000  159.005489         0.01    0.000095
# 99   0.098000  159.437744         0.01    0.000095
# 100  0.099000  159.868872         0.01    0.000095
#
# [101 rows x 4 columns]

# %%
import math

# Define the grain size values
grain_sizes = [i * (5 * math.pow(10, -6)) for i in range(1, 20)]

# Apply grain sizes for df_1 to df_76
for i in range(1, 77):
    # Select the appropriate grain size based on the index within each group
    grain_size_index = (i - 1) % 19
    globals()[f'df_{i}']['grain_size'] = grain_sizes[grain_size_index]

# %%
df_70
# Out:
#        E11   SCAU11  strain_rate  grain_size
# 0    0.000   75.946      0.00001    0.000065
# 1    0.001   76.448      0.00001    0.000065
# 2    0.002   76.921      0.00001    0.000065
# 3    0.003   77.443      0.00001    0.000065
# 4    0.004   77.965      0.00001    0.000065
# ..     ...      ...          ...         ...
# 96   0.096  114.880      0.00001    0.000065
# 97   0.097  115.190      0.00001    0.000065
# 98   0.098  115.500      0.00001    0.000065
# 99   0.099  115.800      0.00001    0.000065
# 100  0.100  116.110      0.00001    0.000065
#
# [101 rows x 4 columns]

# %%
# Loop through each DataFrame from df_1 to df_76 and drop missing values in place
for i in range(1, 77):
    # Access each DataFrame by its variable name using locals() and drop rows with NaN values
    locals()[f'df_{i}'].dropna(inplace=True)

# %%
# Define the smoothing function
def smoothing(df):
  l = df.columns
  for i in l:
    alpha = 0.5
    df[i] = df[i].ewm(alpha=alpha).mean()
  return df

# %%
# Apply the smoothing function to each DataFrame from df_1 to df_76
for i in range(1, 77):
    # Use locals() to access and update each DataFrame variable by name
    locals()[f'df_{i}'] = smoothing(locals()[f'df_{i}'])

# %%
# Concatenate all DataFrames from df_1 to df_76 along rows (axis=0)
df_merged = pd.concat([locals()[f'df_{i}'] for i in range(1, 77)], axis=0)

# %%
df_merged
# Out:
#           E11      SCAU11  strain_rate  grain_size
# 0    0.000000  162.830000      0.01000    0.000005
# 1    0.000667  163.296667      0.01000    0.000005
# 2    0.001429  163.801429      0.01000    0.000005
# 3    0.002267  164.366000      0.01000    0.000005
# 4    0.003161  165.033871      0.01000    0.000005
# ..        ...         ...          ...         ...
# 96   0.095000  111.948127      0.00001    0.000095
# 97   0.096000  112.259063      0.00001    0.000095
# 98   0.097000  112.569532      0.00001    0.000095
# 99   0.098000  112.874766      0.00001    0.000095
# 100  0.099000  113.177383      0.00001    0.000095
#
# [7676 rows x 4 columns]

# %%
# Separate the 'SCAU11' column as the target variable
target = df_merged['SCAU11']

# Drop the 'SCAU11' column from df_merged to avoid duplication
df_merged.drop('SCAU11', axis=1, inplace=True)

# %%
df_merged.head()
# Out:
#         E11  strain_rate  grain_size
# 0  0.000000         0.01    0.000005
# 1  0.000667         0.01    0.000005
# 2  0.001429         0.01    0.000005
# 3  0.002267         0.01    0.000005
# 4  0.003161         0.01    0.000005

# %%
# Set the polynomial degree to 3 for generating polynomial features
degree = 2

# Initialize the PolynomialFeatures transformer with the specified degree
poly_features = PolynomialFeatures(degree=degree)

# %%
df_merged.isna().sum()
# Out:
# E11            0
# strain_rate    0
# grain_size     0
# dtype: int64

# %%
# Generate polynomial features from the df_merged data
strain_poly_train = poly_features.fit_transform(df_merged)

# strain_poly_train now contains the transformed data with polynomial features up to the specified degree

# %%
model = LinearRegression()
model.fit(strain_poly_train,target)#target is stress and strain_poly_train is strain and strain_rate
# Out:
# LinearRegression()

# %%
coefficients = list(model.coef_)
intercept = model.intercept_

# %%
print(coefficients)
print(intercept)
coefficients
# Out:
# [0.0, 581.170941, 24694.1286, -1168663.06, -1368.07412, 12543.1314, -29095.1308, -2102507.11, -9820971.89, 8222685370.0]
# 115.87
# [0.0,
#  581.170941,
#  24694.1286,
#  -1168663.06,
#  -1368.07412,
#  12543.1314,
#  -29095.1308,
#  -2102507.11,
#  -9820971.89,
#  8222685370.0]

# %%
y_pred = model.predict(strain_poly_train)

# %%
# Set the polynomial degree to 3 for generating polynomial features
degree = 2

# Initialize the PolynomialFeatures transformer with the specified degree
poly_features = PolynomialFeatures(degree=degree)

# Generate polynomial features from the df_merged data
strain_poly_train = poly_features.fit_transform(df_merged)

# strain_poly_train now contains the transformed data with polynomial features up to the specified degree
model = LinearRegression()
model.fit(strain_poly_train,target)#target is stress and strain_poly_train is strain and strain_rate
y_pred = model.predict(strain_poly_train)

# %%
coefficients = list(model.coef_)
intercept = model.intercept_
print(coefficients)
print(intercept)
# Out:
# [0.0, 579.7916389711852, 24625.750988934502, -1188053.620649229, -1343.9262079151868, 12552.864010048917, -28006.890242109475, -2094754.7771362613, -9880329.999242757, 8380259972.525759]
# 116.35897794530095

# %%
a = list(df_merged['E11'])
b = list(target)
d = list(y_pred)
c = list(df_merged['strain_rate'])
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(c,a,b, color='b', marker='o', label="Data Points") # Original
ax.scatter(c,a,d, color='r', marker='x', label="Data Points") # Predicted
ax.set_xlabel('strain_rate')
ax.set_ylabel('strain')
ax.set_zlabel('stress')
plt.legend()
plt.show()

# %%
# Plotting 2D graph of strain (E11) vs stress (target)
plt.figure(figsize=(10, 6))

# Plot original data points
plt.scatter(df_merged['E11'], target, color='b', marker='o', label="Actual Stress")

# Plot predicted data points
plt.scatter(df_merged['E11'], y_pred, color='r', marker='x', label="Predicted Stress")

# Setting labels and title
plt.xlabel('Strain (E11)')
plt.ylabel('Stress')
plt.legend()
plt.title('Strain vs Stress')

# Show plot
plt.show()

# %%
r_score = model.score(strain_poly_train,target)
print(r_score)
# Out:
# 0.9485657844102036

# %%
target = list(target)
y_pred = list(y_pred)

for i in range(len(target)):
  print(target[i],y_pred[i],sep='...')
# Out:
# 162.83...146.91623201712468
# 163.29666666666665...147.38575487966816
# 163.80142857142854...147.92088966003573
# 164.36599999999999...148.50773577739173
# 165.0338709677419...149.13208062883766
# 165.69730158730155...149.78157406599277
# 166.41425196850392...150.4466584579038
# 167.10482352941176...151.12054817172285
# 167.83884540117415...151.79872955363624
# 168.53510263929616...152.4783456321502
# 169.26290669272106...153.1576556027368
# 169.9566227106227...153.8356295283465
# 170.67839946282504...154.51167190544743
# 171.36424159189406...155.18544462277015
# 172.0821427045503...155.85675848781744
# 172.76108171206226...156.52550888361665
# 173.46554623066888...157.19163852275207
# 174.13277566061274...157.85511628991478
# 174.79638909604856...158.5159254011809
# 175.49819521731877...159.17405685638482
# 176.16409792618654...159.82950585385262
# 176.81704911876898...160.4822698432193
# 177.47352463764247...161.13234747517544
# 178.13176235805525...161.77973803832236
# ...

# %%
model.coef_
# Out:
# array([ 0.00000000e+00,  5.79791639e+02,  2.46257510e+04, -1.18805362e+06,
#        -1.34392621e+03,  1.25528640e+04, -2.80068902e+04, -2.09475478e+06,
#        -9.88033000e+06,  8.38025997e+09])

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(target,y_pred)
print(mse)
from sklearn.metrics import mean_squared_error, r2_score

# Assuming 'target' is the true values and 'y_pred' is the predicted values
mse = mean_squared_error(target, y_pred)
r2 = r2_score(target, y_pred)

print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# 31.44034706052648
# Mean Squared Error: 31.44034706052648
# R-squared: 0.9485657844102036

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df_merged,target,test_size=0.2)

# %%
strain_poly_train = poly_features.fit_transform(x_train)
strain_poly_test = poly_features.fit_transform(x_test)

# %%
model_new = LinearRegression()
model_new.fit(strain_poly_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_new = model_new.predict(strain_poly_test)

# %%
for i in range(len(y_test)):
  print(y_test[i],y_pred_new[i],sep='...')
# Out:
# 117.87512602242919...127.21067868147168
# 89.14040529817494...95.22873671524871
# 106.88400169373853...113.66460104517927
# 144.39028063859374...146.91726734204823
# 101.87545749411876...105.88408151994321
# 135.09620734172807...133.6401021986539
# 111.11398191581564...114.2985390184814
# 144.44012317127277...141.77625669748
# 114.70866618394007...122.44853195618246
# 93.49700824024904...85.64077265933004
# 128.7629463889116...133.7190754536214
# 129.60725783392417...125.57750293290285
# 135.8836853467792...132.8872295599542
# 99.146...98.60772579699793
# 129.18934515379547...128.62227893558685
# 142.26457629464272...139.32801648858614
# 114.1864636155112...121.85885348316424
# 98.94641174605893...104.88614973837892
# 127.95165563855937...124.66947659743266
# 152.32791185822626...155.023158058276
# 160.3687036435836...165.00225030258542
# 149.76617630211254...150.01541755866464
# 91.03548558866633...82.86551502944103
# 162.1086664631984...167.95422740809477
# ...

# %%
import sklearn.metrics as sm
r2 = round(sm.r2_score(y_test,y_pred_new),5)
print("R2 score:",r2)
mse = mean_squared_error(y_test, y_pred_new)
mse
# Out:
# R2 score: 0.94641
# 33.99528425508121

# %%
model_new.coef_
# Out:
# array([ 0.00000000e+00,  5.81170941e+02,  2.46941286e+04, -1.16866306e+06,
#        -1.36807412e+03,  1.25431314e+04, -2.90951308e+04, -2.10250711e+06,
#        -9.82097189e+06,  8.22268537e+09])

# %%
model_new.intercept_
# Out:
# 115.87587951464256

# %%
def generate_stress_equation(model, feature_names):
    # Get coefficients and intercept from the model
    intercept = model.intercept_
    coefficients = model.coef_

    # Start building the equation with the intercept term
    equation = f"Stress (SCAU11) = {intercept:.5f}"

    # Add terms for each coefficient
    for coef, name in zip(coefficients, feature_names):
        # Skip terms with a coefficient very close to zero
        if abs(coef) > 1e-6:  # threshold to ignore very small coefficients
            equation += f" + ({coef:.5f}) * {name}"

    return equation

# Define the feature names generated by PolynomialFeatures for degree 3
feature_names = [
    "1",                # Constant term
    "E11",              # x1
    "strain_rate",      # x2
    "E11^2",            # x1^2
    "E11 * strain_rate",# x1 * x2
    "strain_rate^2",    # x2^2
    "E11^3",            # x1^3
    "E11^2 * strain_rate", # x1^2 * x2
    "E11 * strain_rate^2", # x1 * x2^2
    "strain_rate^3"     # x2^3a
]

# Generate the equation
equation = generate_stress_equation(model_new, feature_names)
# print(equation)
equation
# Out:
# 'Stress (SCAU11) = 115.87588 + (581.17094) * E11 + (24694.12860) * strain_rate + (-1168663.06234) * E11^2 + (-1368.07412) * E11 * strain_rate + (12543.13143) * strain_rate^2 + (-29095.13076) * E11^3 + (-2102507.10980) * E11^2 * strain_rate + (-9820971.89091) * E11 * strain_rate^2 + (8222685372.73381) * strain_rate^3'

# %%
def generate_stress_equation(coefficients, intercept, feature_names):
    # Start building the equation with the intercept term
    equation = f"Stress (SCAU11) = {intercept:.5f}"

    # Add terms for each coefficient and feature name
    for coef, name in zip(coefficients, feature_names):
        # Skip terms with a coefficient very close to zero
        if abs(coef) > 1e-6:  # threshold to ignore very small coefficients
            # Format each term with parentheses around the coefficient for clarity
            equation += f" + ({coef:.5f}) * {name}"

    return equation

# Define the feature names generated by PolynomialFeatures for degree 3, including grain size
feature_names = [
    "1",                          # Constant term
    "E11",                        # x1
    "strain_rate",                # x2
    "grain_size",                 # x3
    "E11^2",                      # x1^2
    "E11 * strain_rate",          # x1 * x2
    "E11 * grain_size",           # x1 * x3
    "strain_rate^2",              # x2^2
    "strain_rate * grain_size",   # x2 * x3
    "grain_size^2",               # x3^2
    "E11^3",                      # x1^3
    "E11^2 * strain_rate",        # x1^2 * x2
    "E11^2 * grain_size",         # x1^2 * x3
    "E11 * strain_rate^2",        # x1 * x2^2
    "E11 * strain_rate * grain_size", # x1 * x2 * x3
    "E11 * grain_size^2",         # x1 * x3^2
    "strain_rate^3",              # x2^3
    "strain_rate^2 * grain_size", # x2^2 * x3
    "strain_rate * grain_size^2", # x2 * x3^2
    "grain_size^3"                # x3^3
]

# Use the coefficients and intercept obtained from the trained model
coefficients = [
    0.00000000e+00,  5.53156279e+02,  1.55295186e+05, -2.35813426e+06,
    -1.54581791e+03,  9.73297059e+04, -6.35197856e+04, -1.39774263e+08,
    -9.90914136e+07,  3.83348662e+10,  2.84511901e+03, -4.31520211e+04,
    -1.45788982e+06, -7.87678721e+06,  3.94260616e+06,  1.62417993e+09,
    1.24709796e+10,  6.40542810e+09,  2.31043982e+11, -2.04210579e+14
]
intercept = 121.11038148981153

# Generate the equation
equation = generate_stress_equation(coefficients, intercept, feature_names)
print(equation)
# Out:
# Stress (SCAU11) = 121.11038 + (553.15628) * E11 + (155295.18600) * strain_rate + (-2358134.26000) * grain_size + (-1545.81791) * E11^2 + (97329.70590) * E11 * strain_rate + (-63519.78560) * E11 * grain_size + (-139774263.00000) * strain_rate^2 + (-99091413.60000) * strain_rate * grain_size + (38334866200.00000) * grain_size^2 + (2845.11901) * E11^3 + (-43152.02110) * E11^2 * strain_rate + (-1457889.82000) * E11^2 * grain_size + (-7876787.21000) * E11 * strain_rate^2 + (3942606.16000) * E11 * strain_rate * grain_size + (1624179930.00000) * E11 * grain_size^2 + (12470979600.00000) * strain_rate^3 + (6405428100.00000) * strain_rate^2 * grain_size + (231043982000.00000) * strain_rate * grain_size^2 + (-204210579000000.00000) * grain_size^3

# %%
def generate_stress_equation(coefficients, intercept, feature_names):
    # Start building the equation with the intercept term
    equation = f"Stress (SCAU11) = {intercept:.5f}"

    # Add terms for each coefficient and feature name
    for coef, name in zip(coefficients, feature_names):
        # Skip terms with a coefficient very close to zero
        if abs(coef) > 1e-6:  # threshold to ignore very small coefficients
            # Format each term with parentheses around the coefficient for clarity
            equation += f" + ({coef:.5f}) * {name}"

    return equation

# Define the feature names for a 2nd-degree polynomial
feature_names = [
    "1",                          # Constant term
    "E11",                        # x1
    "strain_rate",                # x2
    "grain_size",                 # x3
    "E11^2",                      # x1^2
    "E11 * strain_rate",          # x1 * x2
    "E11 * grain_size",           # x1 * x3
    "strain_rate^2",              # x2^2
    "strain_rate * grain_size",   # x2 * x3
    "grain_size^2"                # x3^2
]

# Use the coefficients and intercept obtained from the trained model for 2nd-degree polynomial
coefficients = [
    0.00000000e+00,  5.81170941e+02,  2.46941286e+04, -1.16866306e+06,
    -1.36807412e+03,  1.25431314e+04, -2.90951308e+04, -2.10250711e+06,
    -9.82097189e+06,  8.22268537e+09
]
intercept = 115.87

# Generate the equation
equation = generate_stress_equation(coefficients, intercept, feature_names)
print(equation)
# Out:
# Stress (SCAU11) = 115.87000 + (581.17094) * E11 + (24694.12860) * strain_rate + (-1168663.06000) * grain_size + (-1368.07412) * E11^2 + (12543.13140) * E11 * strain_rate + (-29095.13080) * E11 * grain_size + (-2102507.11000) * strain_rate^2 + (-9820971.89000) * strain_rate * grain_size + (8222685370.00000) * grain_size^2

# %%
def calculate_stress(E11, strain_rate):
    # Coefficients from the given equation
    intercept = 79.48234
    coef_E11 = 541.25902
    coef_strain_rate = 149295.46603
    coef_E11_squared = -1226.78951
    coef_E11_strain_rate = 102286.06000
    coef_strain_rate_squared = -137990665.76318
    coef_E11_cubed = -144.25389
    coef_E11_squared_strain_rate = -45714.88456
    coef_E11_strain_rate_squared = -8310358.30173
    coef_strain_rate_cubed = 12342145698.93503
    
    # Calculate stress using the polynomial terms
    stress = (
        intercept
        + coef_E11 * E11
        + coef_strain_rate * strain_rate
        + coef_E11_squared * E11**2
        + coef_E11_strain_rate * E11 * strain_rate
        + coef_strain_rate_squared * strain_rate**2
        + coef_E11_cubed * E11**3
        + coef_E11_squared_strain_rate * E11**2 * strain_rate
        + coef_E11_strain_rate_squared * E11 * strain_rate**2
        + coef_strain_rate_cubed * strain_rate**3
    )
    
    return stress

# %%
# Sample test case
strain = 0.02   # Example strain value
strain_rate = 5e-4  # Example strain rate value

# Calculate stress
stress = calculate_stress(strain, strain_rate)
print("Calculated Stress (SCAU11):", stress)
# Out:
# Calculated Stress (SCAU11): 132.48065118303123

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('ujjwal.csv')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from CSV
df = pd.read_csv('ujjwal.csv')

# Create a scatter plot
plt.scatter(df['Strain'], df['Stress'])

# Add labels for clarity
plt.xlabel('Strain')
plt.ylabel('Stress')
plt.title('Strain vs. Stress')

# Show plot
plt.show()
